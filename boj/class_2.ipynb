# %% [markdown]
# ## 웰컴 키트
# https://www.acmicpc.net/problem/30802

# %%
import sys
input = sys.stdin.readline

n = int(input())
arr = list(map(int, input().split()))
t, p = map(int, input().split())

t_cnt = 0

# 티셔츠 묶음 계산 (올림)
for t_no in arr:
    if t_no == 0:  # 0개면 안 사도 됨
        continue
    # 올림: (개수 + 묶음크기 - 1) // 묶음크기
    t_cnt += (t_no + t - 1) // t

# 펜 묶음과 낱개
p_set_cnt = n // p  # 정수 나누기!
p_cnt = n % p

print(t_cnt)
print(f"{p_set_cnt} {p_cnt}")

# %% [markdown]
# ## 달팽이는 올라가고 싶다
# https://www.acmicpc.net/problem/2869

# %%
import sys
input = sys.stdin.readline

A, B, V = map(int, input().split())
cnt = 0

for i in range(1, V + 1):
    if V - A <= 0:
        cnt += 1
        break
    V -= (A-B)
    cnt += 1

print(cnt)

# %%
# 정답 코드
import sys
input = sys.stdin.readline

A, B, V = map(int, input().split())

# 마지막 날 제외한 높이
need = V - A

# 하루에 올라가는 순 높이
per_day = A - B

# 올림 계산
if need <= 0:  # 첫날에 바로 도착
    print(1)
else:
    days = (need + per_day - 1) // per_day + 1  # 마지막 날 추가
    print(days)

# %% [markdown]
# ## 수 정렬하기 3
# https://www.acmicpc.net/problem/10989

# %%
import sys
input = sys.stdin.readline


data = [input().strip() for _ in range(n)]
## 모르겠음 ㅠㅠ

# %%
# 정답 코드, 메모리 관리를 위한 계수 정리임
import sys
input = sys.stdin.readline

n = int(input())

# 1~10,000 범위의 개수만 카운트
count = [0] * 10001  # 인덱스 0은 안 씀

# 입력받으면서 바로 카운트
for _ in range(n):
    num = int(input())
    count[num] += 1

# 카운트한 만큼 출력
for i in range(1, 10001):
    if count[i] > 0:
        for _ in range(count[i]):
            print(i)

# %% [markdown]
# ## ISBN
# https://www.acmicpc.net/problem/14626

# %%
import sys
input = sys.stdin.readline

isbn = int(input())
## 모르겠슨

# %%
isbn = input().strip()

# * 위치와 가중치 찾기
total = 0
star_weight = 0

for i in range(13):
    if isbn[i] == '*':
        star_weight = 1 if i % 2 == 0 else 3
    else:
        weight = 1 if i % 2 == 0 else 3
        total += int(isbn[i]) * weight

# 0~9 넣어보기
for num in range(10):
    if (total + num * star_weight) % 10 == 0:
        print(num)
        break

# %% [markdown]
# ## FizzBuzz
# https://www.acmicpc.net/problem/28702

# %%
### 모르겠슨...

# %%
import sys
input = sys.stdin.readline

# 3줄 입력
a = input().strip()
b = input().strip()
c = input().strip()

# 숫자 찾기
next_num = 0

if a.isdigit():  # 첫 줄이 숫자면
    next_num = int(a) + 3
elif b.isdigit():  # 둘째 줄이 숫자면
    next_num = int(b) + 2
elif c.isdigit():  # 셋째 줄이 숫자면
    next_num = int(c) + 1

# FizzBuzz 판정
if next_num % 15 == 0:  # 3과 5의 배수
    print("FizzBuzz")
elif next_num % 3 == 0:  # 3의 배수만
    print("Fizz")
elif next_num % 5 == 0:  # 5의 배수만
    print("Buzz")
else:
    print(next_num)

# %% [markdown]
# ## 덩치
# https://www.acmicpc.net/problem/7568

# %%
n = int(input())
big = list(map(int, input().split()))

## 몰겠슨...

# %%
import sys
input = sys.stdin.readline

n = int(input())
people = []

# 입력 받기
for _ in range(n):
    w, h = map(int, input().split())
    people.append((w, h))

# 각 사람의 등수 계산
ranks = []
for i in range(n):
    rank = 1  # 기본 1등
    for j in range(n):
        if i == j:  # 자기 자신은 제외
            continue
        # 둘 다 작으면 등수 +1
        if people[i][0] < people[j][0] and people[i][1] < people[j][1]:
            rank += 1
    ranks.append(rank)

# 출력
print(' '.join(map(str, ranks)))

# %% [markdown]
# ## 좌표 정렬하기 2
# https://www.acmicpc.net/problem/11651
#
# ### 문제
# 2차원 평면 위의 점 N개가 주어진다. 좌표를 y좌표가 증가하는 순으로, y좌표가 같으면 x좌표가 증가하는 순서로 정렬한 다음 출력하는 프로그램을 작성하시오.
#
# ### 입력
# 첫째 줄에 점의 개수 N (1 ≤ N ≤ 100,000)이 주어진다. 둘째 줄부터 N개의 줄에는 i번점의 위치 xi와 yi가 주어진다. (-100,000 ≤ xi, yi ≤ 100,000) 좌표는 항상 정수이고, 위치가 같은 두 점은 없다.
#
# ### 출력
# 첫째 줄부터 N개의 줄에 점을 정렬한 결과를 출력한다.
#
# ### 예제 입력 1
# ```
# 5
# 0 4
# 1 2
# 1 -1
# 2 2
# 3 3
# ```
# ### 예제 출력 1
# ```
# 1 -1
# 1 2
# 2 2
# 3 3
# 0 4
# ```

# %%
n = int(input())
points = []

for _ in range(n):
    x, y = map(int, input().split())
    points.append((y, x))  # (y, x) 순서로 저장

points.sort()  # 자동으로 y 기준 정렬, y 같으면 x 기준 정렬

for y, x in points:
    print(x, y)

# %% [markdown]
# ## 카드2
# https://www.acmicpc.net/problem/2164
#
# ### 문제
# N장의 카드가 있다. 각각의 카드는 차례로 1부터 N까지의 번호가 붙어 있으며, 1번 카드가 제일 위에, N번 카드가 제일 아래인 상태로 순서대로 카드가 놓여 있다.
#
# 이제 다음과 같은 동작을 카드가 한 장 남을 때까지 반복하게 된다. 우선, 제일 위에 있는 카드를 바닥에 버린다. 그 다음, 제일 위에 있는 카드를 제일 아래에 있는 카드 밑으로 옮긴다.
#
# 예를 들어 N=4인 경우를 생각해 보자. 카드는 제일 위에서부터 1234 의 순서로 놓여있다. 1을 버리면 234가 남는다. 여기서 2를 제일 아래로 옮기면 342가 된다. 3을 버리면 42가 되고, 4를 밑으로 옮기면 24가 된다. 마지막으로 2를 버리고 나면, 남는 카드는 4가 된다.
#
# N이 주어졌을 때, 제일 마지막에 남게 되는 카드를 구하는 프로그램을 작성하시오.
#
# ### 입력
# 첫째 줄에 정수 N(1 ≤ N ≤ 500,000)이 주어진다.
#
# ### 출력
# 첫째 줄에 남게 되는 카드의 번호를 출력한다.
#
# ### 예제 입력 1
# ```
# 6
# ```
# ### 예제 출력 1
# ```
# 4
# ```

# %% [markdown]
# 1. 문제 이해
#
# N장의 카드가 1~N 순서로 쌓여 있음
# 반복: 맨 위 카드 버리기 → 그 다음 카드 맨 아래로 이동
# 마지막 남은 카드 번호 출력
# 엣지 케이스: N=1이면 바로 1 출력
#
#
# 2. 복잡도 역산
#
# N ≤ 500,000 → O(n) 또는 O(n log n) 허용
#
#
# 3. 연산 패턴 파악
#
# 맨 앞에서 꺼내기 (dequeue)
# 맨 뒤에 넣기 (enqueue)
# → FIFO 패턴 → Queue
#
#
# 4. 자료구조 선택<br>
#
# Queue (deque 사용하면 더 효율적)
# 배열 + 포인터로도 가능하지만 deque가 직관적
#
#
# 5. 알고리즘 설계<br>
# 브루트포스 = 곧 최적해
#     1. 1~N을 큐에 삽입
#     2. 큐 크기가 1이 될 때까지:
#         - 맨 앞 카드 버리기 (pop)
#         - 맨 앞 카드 맨 뒤로 이동 (pop → push)
#     3. 남은 카드 출력
#
# 6. 코드<br>
# 밑에 확인
#
# 7. 검증<br>
# N과정정답1[1] → 바로 종료14[1,2,3,4] → [3,4,2] → [2,3] → [3]36[1..6] → ... → [4]4<br><br>
#
# - 시간복잡도: O(n) — 각 카드가 최대 2번 연산
# - 공간복잡도: O(n)

# %%
from collections import deque

n = int(input())
q = deque(range(1, n + 1))

while len(q) > 1:
    q.popleft()
    q.append(q.popleft())

print(q[0])

# %% [markdown]
# ## 설탕 배달
# https://www.acmicpc.net/problem/2839
#
# ### 문제
# 상근이는 요즘 설탕공장에서 설탕을 배달하고 있다. 상근이는 지금 사탕가게에 설탕을 정확하게 N킬로그램을 배달해야 한다. 설탕공장에서 만드는 설탕은 봉지에 담겨져 있다. 봉지는 3킬로그램 봉지와 5킬로그램 봉지가 있다.
#
# 상근이는 귀찮기 때문에, 최대한 적은 봉지를 들고 가려고 한다. 예를 들어, 18킬로그램 설탕을 배달해야 할 때, 3킬로그램 봉지 6개를 가져가도 되지만, 5킬로그램 3개와 3킬로그램 1개를 배달하면, 더 적은 개수의 봉지를 배달할 수 있다.
#
# 상근이가 설탕을 정확하게 N킬로그램 배달해야 할 때, 봉지 몇 개를 가져가면 되는지 그 수를 구하는 프로그램을 작성하시오.
#
# ### 입력
# 첫째 줄에 N이 주어진다. (3 ≤ N ≤ 5000)
#
# ### 출력
# 상근이가 배달하는 봉지의 최소 개수를 출력한다. 만약, 정확하게 N킬로그램을 만들 수 없다면 -1을 출력한다.
#
# 예제 입력 1 <br>
# 18<br>
# 예제 출력 1 <br>
# 4<br><br>
# 예제 입력 2 <br>
# 4<br>
# 예제 출력 2 <br>
# -1<br><br>
# 예제 입력 3 <br>
# 6<br>
# 예제 출력 3 <br>
# 2<br><br>
# 예제 입력 4 <br>
# 9<br>
# 예제 출력 4 <br>
# 3<br><br>
# 예제 입력 5 <br>
# 11<br>
# 예제 출력 5 <br>
# 3

# %% [markdown]
# 1. 문제 이해
#
# N킬로그램 설탕을 3kg, 5kg 봉지로 정확히 담기
# 봉지 개수 최소화
# 불가능하면 -1 출력
# 엣지 케이스: 1, 2는 무조건 -1
#
#
# 2. 복잡도 역산
#
# N ≤ 5,000 → O(n)까지 여유롭게 허용
#
#
# 3. 연산 패턴 파악
#
# 최소 봉지 개수 → 큰 봉지(5kg)를 최대한 우선 사용
# 매 순간 최선 = 전체 최선 → 그리디
#
#
# 4. 알고리즘 설계<br>
# 5kg 봉지를 최대한 쓰되, 나머지가 3의 배수가 될 때까지 5kg 봉지를 하나씩 줄여보기<br>
# 5kg 봉지 수를 최대치(N//5)부터 0까지 줄이면서:<br>
#     나머지 = N - (5 * i)<br>
#     나머지 % 3 == 0 이면 → i + 나머지//3 이 정답<br>
# 끝까지 못 찾으면 -1<br>
#
# 5. 코드<br>
#
#
# 6. 검증
# N5kg봉지3kg봉지총 개수111 (5)2 (6)31204440→나머지4, 불가--1183 (15)1 (3)4
#
# - 시간복잡도: O(n/5) → 사실상 O(n)
# - 공간복잡도: O(1)

# %%
n = int(input())

count = -1
for i in range(n // 5, -1, -1):
    remainder = n - 5 * i
    if remainder % 3 == 0:
        count = i + remainder // 3
        break

print(count)
